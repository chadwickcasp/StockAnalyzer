# %%
# Many-to-one LSTM network (Divides the network into n layers evenly starting from the input dimension)
# i.e. a 300 length input vector with 2 levels is split into a 150 node layer and a 1 node layer
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
from math import *
import time
import re
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

# %%
def fullprint(*args, **kwargs):
  from pprint import pprint
  import numpy
  opt = numpy.get_printoptions()
  numpy.set_printoptions(threshold='nan')
  pprint(*args, **kwargs)
  numpy.set_printoptions(**opt)

# %%
NUM_LAYERS = 2
VEC_SIZE = 300
hidden_layer_sizes = [int(VEC_SIZE - i * VEC_SIZE/NUM_LAYERS) for i in range(NUM_LAYERS)] + [1]
print(hidden_layer_sizes)
# Out:
# [300, 150, 1]

# %%
# Make headline embeddings
print("Loading model...")
start = time.time()
model = Doc2Vec.load('NYTimesYearDocVecs.bin')
model.delete_temporary_training_data(keep_doctags_vectors=True, 
                                     keep_inference=True)
print("Model loaded in {}s".format(time.time()-start))
# Out:
# Loading model...
# Model loaded in 106.238114119s

# %%
dv = model.docvecs
doc_tags = dv.offset2doctag
date_tags = [re.match('[0-9]{4}-[0-9]{2}-[0-9]{2}', tag).group()
             for tag in doc_tags]
date_tags = [tuple(int(t) for t in tag.split('-')) for tag in date_tags]
date_tags_uniq = list(set(date_tags))
uniq_date_tags = sorted(sorted(sorted(date_tags_uniq, key=lambda x: x[2]),key=lambda x: x[1]),key=lambda x: x[0])
# print(uniq_date_tags)
# Out:
# [(2008, 3, 1), (2008, 3, 2), (2008, 3, 3), (2008, 3, 4), (2008, 3, 5), (2008, 3, 6), (2008, 3, 7), (2008, 3, 8), (2008, 3, 9), (2008, 3, 10), (2008, 3, 11), (2008, 3, 12), (2008, 3, 13), (2008, 3, 14), (2008, 3, 15), (2008, 3, 16), (2008, 3, 17), (2008, 3, 18), (2008, 3, 19), (2008, 3, 20), (2008, 3, 21), (2008, 3, 22), (2008, 3, 23), (2008, 3, 24), (2008, 3, 25), (2008, 3, 26), (2008, 3, 27), (2008, 3, 28), (2008, 3, 29), (2008, 3, 30), (2008, 3, 31), (2008, 4, 1), (2008, 4, 2), (2008, 4, 3), (2008, 4, 4), (2008, 4, 5), (2008, 4, 6), (2008, 4, 7), (2008, 4, 8), (2008, 4, 9), (2008, 4, 10), (2008, 4, 11), (2008, 4, 12), (2008, 4, 13), (2008, 4, 14), (2008, 4, 15), (2008, 4, 16), (2008, 4, 17), (2008, 4, 18), (2008, 4, 19), (2008, 4, 20), (2008, 4, 21), (2008, 4, 22), (2008, 4, 23), (2008, 4, 24), (2008, 4, 25), (2008, 4, 26), (2008, 4, 27), (2008, 4, 28), (2008, 4, 29), (2008, 4, 30), (2008, 5, 1), (2008, 5, 2), (2008, 5, 3), (2008, 5, 4), (2008, 5, 5), (2008, 5, 6), (2008, 5, 7), (2008, 5, 8), (2008, 5, 9), (2008, 5, 10), (2008, 5, 11), (2008, 5, 12), (2008, 5, 13), (2008, 5, 14), (2008, 5, 15), (2008, 5, 16), (2008, 5, 17), (2008, 5, 18), (2008, 5, 19), (2008, 5, 20), (2008, 5, 21), (2008, 5, 22), (2008, 5, 23), (2008, 5, 24), (2008, 5, 25), (2008, 5, 26), (2008, 5, 27), (2008, 5, 28), (2008, 5, 29), (2008, 5, 30), (2008, 5, 31), (2008, 6, 1), (2008, 6, 2), (2008, 6, 3), (2008, 6, 4), (2008, 6, 5), (2008, 6, 6), (2008, 6, 7), (2008, 6, 8), (2008, 6, 9), (2008, 6, 10), (2008, 6, 11), (2008, 6, 12), (2008, 6, 13), (2008, 6, 14), (2008, 6, 15), (2008, 6, 16), (2008, 6, 17), (2008, 6, 18), (2008, 6, 19), (2008, 6, 20), (2008, 6, 21), (2008, 6, 22), (2008, 6, 23), (2008, 6, 24), (2008, 6, 25), (2008, 6, 26), (2008, 6, 27), (2008, 6, 28), (2008, 6, 29), (2008, 6, 30), (2008, 7, 1), (2008, 7, 2), (2008, 7, 3), (2008, 7, 4), (2008, 7, 5), (2008, 7, 6), (2008, 7, 7), (2008, 7, 8), (2008, 7, 9), (2008, 7, 10), (2008, 7, 11), (2008, 7, 12), (2008, 7, 13), (2008, 7, 14), (2008, 7, 15), (2008, 7, 16), (2008, 7, 17), (2008, 7, 18), (2008, 7, 19), (2008, 7, 20), (2008, 7, 21), (2008, 7, 22), (2008, 7, 23), (2008, 7, 24), (2008, 7, 25), (2008, 7, 26), (2008, 7, 27), (2008, 7, 28), (2008, 7, 29), (2008, 7, 30), (2008, 7, 31), (2008, 8, 1), (2008, 8, 2), (2008, 8, 3), (2008, 8, 4), (2008, 8, 5), (2008, 8, 6), (2008, 8, 7), (2008, 8, 8), (2008, 8, 9), (2008, 8, 10), (2008, 8, 11), (2008, 8, 12), (2008, 8, 13), (2008, 8, 14), (2008, 8, 15), (2008, 8, 16), (2008, 8, 17), (2008, 8, 18), (2008, 8, 19), (2008, 8, 20), (2008, 8, 21), (2008, 8, 22), (2008, 8, 23), (2008, 8, 24), (2008, 8, 25), (2008, 8, 26), (2008, 8, 27), (2008, 8, 28), (2008, 8, 29), (2008, 8, 30), (2008, 8, 31), (2008, 9, 1), (2008, 9, 2), (2008, 9, 3), (2008, 9, 4), (2008, 9, 5), (2008, 9, 6), (2008, 9, 7), (2008, 9, 8), (2008, 9, 9), (2008, 9, 10), (2008, 9, 11), (2008, 9, 12), (2008, 9, 13), (2008, 9, 14), (2008, 9, 15), (2008, 9, 16), (2008, 9, 17), (2008, 9, 18), (2008, 9, 19), (2008, 9, 20), (2008, 9, 21), (2008, 9, 22), (2008, 9, 23), (2008, 9, 24), (2008, 9, 25), (2008, 9, 26), (2008, 9, 27), (2008, 9, 28), (2008, 9, 29), (2008, 9, 30), (2008, 10, 1), (2008, 10, 2), (2008, 10, 3), (2008, 10, 4), (2008, 10, 5), (2008, 10, 6), (2008, 10, 7), (2008, 10, 8), (2008, 10, 9), (2008, 10, 10), (2008, 10, 11), (2008, 10, 12), (2008, 10, 13), (2008, 10, 14), (2008, 10, 15), (2008, 10, 16), (2008, 10, 17), (2008, 10, 18), (2008, 10, 19), (2008, 10, 20), (2008, 10, 21), (2008, 10, 22), (2008, 10, 23), (2008, 10, 24), (2008, 10, 25), (2008, 10, 26), (2008, 10, 27), (2008, 10, 28), (2008, 10, 29), (2008, 10, 30), (2008, 10, 31), (2008, 11, 1), (2008, 11, 2), (2008, 11, 3), (2008, 11, 4), (2008, 11, 5), (2008, 11, 6), (2008, 11, 7), (2008, 11, 8), (2008, 11, 9), (2008, 11, 10), (2008, 11, 11), (2008, 11, 12), (2008, 11, 13), (2008, 11, 14), (2008, 11, 15), (2008, 11, 16), (2008, 11, 17), (2008, 11, 18), (2008, 11, 19), (2008, 11, 20), (2008, 11, 21), (2008, 11, 22), (2008, 11, 23), (2008, ...

# %%
date_str_tags = [str(dt.date(year=tag[0], month=tag[1], day=tag[2])) for tag in uniq_date_tags]
# print(date_str_tags)
from collections import Counter, defaultdict
counts = Counter(date_str_tags)
print(counts)
# [model.docvecs[tag] for tag in date_str_tags][:2]
daily_headline = defaultdict(list)
for tag in date_str_tags:
#     print(tag)
    for i in range(counts[tag]):
        print(tag, i)
        docvec = dv[str(tag)+'-'+str(i)]
        print(docvec)
        daily_headline[tag] = daily_headline[tag].append(docvec)
now = dt.datetime.now()
now = dt.date(year=now.year, month=now.month, day=now.day)
print(dv)
print(daily_headline)
print(daily_headline[str(now)])
# Out:
# Counter({'2017-08-29': 1, '2008-11-17': 1, '2008-11-16': 1, '2008-11-15': 1, '2008-11-14': 1, '2008-11-13': 1, '2008-11-12': 1, '2008-11-11': 1, '2008-11-10': 1, '2015-11-11': 1, '2015-11-10': 1, '2015-11-13': 1, '2015-11-12': 1, '2015-11-15': 1, '2015-11-14': 1, '2008-11-19': 1, '2008-11-18': 1, '2016-03-23': 1, '2017-10-01': 1, '2012-07-01': 1, '2016-03-26': 1, '2016-11-28': 1, '2016-03-27': 1, '2018-01-16': 1, '2016-03-28': 1, '2016-03-29': 1, '2017-02-23': 1, '2015-11-19': 1, '2015-11-18': 1, '2013-01-01': 1, '2015-12-15': 1, '2013-01-03': 1, '2013-01-02': 1, '2013-01-05': 1, '2013-01-04': 1, '2012-03-28': 1, '2013-01-06': 1, '2013-01-09': 1, '2013-01-08': 1, '2015-12-18': 1, '2015-12-19': 1, '2014-03-31': 1, '2014-03-30': 1, '2017-10-06': 1, '2012-03-29': 1, '2013-04-17': 1, '2013-04-16': 1, '2012-03-19': 1, '2012-02-27': 1, '2016-09-08': 1, '2016-09-09': 1, '2010-05-08': 1, '2010-05-09': 1, '2010-05-06': 1, '2010-05-07': 1, '2010-05-04': 1, '2010-05-05': 1, '2010-05-02': 1, '2010-05-03': 1, '2012-03-17': 1, '2010-05-01': 1, '2017-04-15': 1, '2008-04-28': 1, '2017-04-17': 1, '2012-02-24': 1, '2017-04-11': 1, '2017-04-10': 1, '2017-04-13': 1, '2008-04-29': 1, '2012-02-23': 1, '2017-04-19': 1, '2017-04-18': 1, '2012-02-22': 1, '2012-02-21': 1, '2012-02-20': 1, '2016-07-10': 1, '2018-01-31': 1, '2017-08-24': 1, '2017-08-25': 1, '2017-03-09': 1, '2017-03-08': 1, '2016-05-31': 1, '2016-05-30': 1, '2017-08-22': 1, '2017-08-23': 1, '2017-03-03': 1, '2017-03-02': 1, '2017-03-01': 1, '2017-03-07': 1, '2008-04-22': 1, '2017-03-05': 1, '2017-03-04': 1, '2014-08-09': 1, '2014-08-08': 1, '2008-04-23': 1, '2014-08-01': 1, '2014-08-03': 1, '2014-08-02': 1, '2014-08-05': 1, '2014-08-04': 1, '2014-08-07': 1, '2014-08-06': 1, '2011-05-07': 1, '2011-05-06': 1, '2011-05-05': 1, '2011-05-04': 1, '2011-05-03': 1, '2011-05-02': 1, '2011-05-01': 1, '2011-05-09': 1, '2011-05-08': 1, '2014-11-14': 1, '2014-11-15': 1, '2014-11-16': 1, '2014-11-17': 1, '2014-11-10': 1, '2014-11-11': 1, '2014-11-12': 1, '2014-11-13': 1, '2014-11-18': 1, '2014-11-19': 1, '2015-12-24': 1, '2016-08-13': 1, '2011-12-02': 1, '2012-04-10': 1, '2012-04-11': 1, '2012-04-12': 1, '2012-04-13': 1, '2012-04-14': 1, '2012-04-15': 1, '2012-04-16': 1, '2012-04-17': 1, '2012-04-18': 1, '2012-04-19': 1, '2014-12-13': 1, '2014-12-12': 1, '2014-12-15': 1, '2014-12-14': 1, '2014-12-17': 1, '2014-12-16': 1, '2012-09-10': 1, '2009-10-31': 1, '2009-10-30': 1, '2011-06-30': 1, '2011-10-01': 1, '2011-10-03': 1, '2011-10-02': 1, '2011-10-05': 1, '2011-10-04': 1, '2011-10-07': 1, '2011-10-06': 1, '2011-10-09': 1, '2011-10-08': 1, '2017-11-28': 1, '2017-11-29': 1, '2017-11-26': 1, '2017-11-27': 1, '2017-11-24': 1, '2017-11-25': 1, '2017-11-22': 1, '2017-11-23': 1, '2017-11-20': 1, '2017-11-21': 1, '2015-06-24': 1, '2013-10-29': 1, '2011-03-29': 1, '2015-06-25': 1, '2013-10-25': 1, '2013-10-24': 1, '2013-10-27': 1, '2011-03-28': 1, '2013-10-21': 1, '2013-10-20': 1, '2013-10-23': 1, '2012-12-03': 1, '2012-07-15': 1, '2012-07-14': 1, '2012-07-17': 1, '2012-07-16': 1, '2012-07-11': 1, '2012-07-10': 1, '2012-07-13': 1, '2012-07-12': 1, '2012-07-19': 1, '2012-07-18': 1, '2011-03-23': 1, '2015-01-28': 1, '2012-12-04': 1, '2011-03-22': 1, '2010-09-08': 1, '2010-09-09': 1, '2012-05-30': 1, '2010-09-02': 1, '2010-09-03': 1, '2010-09-01': 1, '2010-09-06': 1, '2010-09-07': 1, '2010-09-04': 1, '2010-09-05': 1, '2009-06-27': 1, '2009-06-26': 1, '2009-06-25': 1, '2009-06-24': 1, '2008-06-08': 1, '2008-06-09': 1, '2009-06-21': 1, '2009-06-20': 1, '2008-06-04': 1, '2008-06-05': 1, '2008-06-06': 1, '2008-06-07': 1, '2008-06-01': 1, '2008-06-02': 1, '2008-06-03': 1, '2017-12-05': 1, '2017-06-22': 1, '2017-12-07': 1, '2017-12-06': 1, '2017-12-01': 1, '2017-12-03': 1, '2017-06-23': 1, '2017-12-09': 1, '2016-06-07': 1, '2015-05-03': 1, '2012-11-16': 1, '2012-02-01': 1, '2012-06-20': 1, '2015-05-07': 1, '2015-05-06': 1, '2015-05-05': 1, '2012-11-17': 1, '2017-06-26': 1, '2015-05-09': 1, '2015-05-08': 1, '2014-04-16': ...
# ('2008-03-01', 0)
# [ 0.00122895 -0.00319512 -0.04630608 -0.01179086 -0.00758146  0.03244029
#   0.01311348  0.00944428  0.00858522 -0.02134052 -0.04421346  0.00231954
#   0.00398397 -0.06965519 -0.00718051  0.02210177 -0.00291119  0.00521686
#  -0.01754511 -0.04154429  0.00167907  0.02724909 -0.01759871 -0.00444307
#  -0.01350729  0.02412924  0.03431303 -0.01907598 -0.00170735  0.00362133
#   0.00668858  0.0352683  -0.00994442 -0.0383457   0.02339975  0.0304784
#   0.01088636  0.00267411 -0.0025266   0.01057689 -0.02099624 -0.02996943
#   0.03199447  0.01116376 -0.00444105  0.01817389 -0.00675858  0.00221758
#  -0.0301778  -0.02140576 -0.01379227  0.01586616  0.00747603  0.03574643
#  -0.00122531 -0.01510954 -0.02082516  0.01622295 -0.00016662 -0.01365491
#   0.0002394   0.01154713 -0.02677621  0.01202686  0.00191463  0.00020489
#   0.01668291 -0.02316923 -0.01052157  0.03642658 -0.04667936 -0.02075985
#   0.00058815  0.01487984  0.00185085  0.01010558  0.03544924 -0.00651751
#   0.01350738  0.02610242  0.02187011 -0.0342278  -0.02367294 -0.00844323
#  -0.03846037  0.02481102  0.01029015  0.00580767 -0.01817887 -0.02526516
#   0.02060516  0.00105931 -0.01588263 -0.02622294 -0.00509492  0.02090675
#  -0.00718684 -0.02074786  0.03558837  0.0113102  -0.02456429 -0.00324906
#  -0.0215074  -0.01568489  0.03506653 -0.0132247   0.02477045  0.04066571
#   0.0248622   0.01079899  0.00177262  0.01368471  0.0137704   0.01850369
#  -0.0144555  -0.04322645  0.00393662 -0.00841414  0.01140306  0.00648775
#   0.00301219 -0.01413284  0.00481141  0.00374457  0.014923   -0.02892426
#  -0.00042724 -0.01148397 -0.00762901 -0.01698377  0.00814791  0.00338752
#  -0.00042893 -0.02769418  0.00105009 -0.00965909 -0.01178724  0.00133031
#  -0.01767354  0.01105985  0.02961031 -0.01150065 -0.00600469  0.01657244
#  -0.00141692 -0.01334423 -0.00053913  0.02179202  0.02336142  0.02671873
#  -0.01779913  0.00102778  0.02041518  0.01300845 -0.00941723 -0.00896107
#   0.01351338  0.00591534 -0.01265993 -0.02688941 -0.00293396 -0.00452927
#   0.02800308  0.00971001  0.03553479 -0.00193992  0.03127335  0.01186705
#   0.01517128 -0.01906585  0.00591362  0.003846    0.02284139  0.03900164
#  -0.01910464  0.00883773 -0.01368352  0.01758906  0.02775906  0.01961563
#  -0.00140341  0.01918888 -0.00834053 -0.00152843  0.00366617  0.00749915
#   0.00338511  0.02594805 -0.01846434  0.02378455 -0.03713276  0.01736535
#   0.0225696   0.00887687  0.02565271  0.00096864 -0.01277695 -0.00970598
#  -0.02285893 -0.01196341 -0.00616816  0.01288595 -0.01404601  0.05014673
#  -0.01610514 -0.01309076 -0.00936647  0.00915207 -0.02345065 -0.009625
#   0.01748461  0.01174837  0.0025392   0.01171955 -0.01035979  0.02256872
#   0.01719056  0.02192985 -0.02422388  0.00985364 -0.00895328 -0.00954327
#   0.01938977  0.02456179  0.00352349  0.00296302  0.02211855  0.03907085
#   0.00678245 -0.0312699  -0.0111703   0.00348611  0.0340317  -0.01472926
#   0.01342492  0.0219852   0.00306031  0.01194776 -0.00687751  0.01071745
#   0.00262271  0.03102312 -0.04388876 -0.01808201 -0.00671756 -0.02130773
#  -0.00574539 -0.02236229  0.00866991  0.0182498  -0.0152648  -0.00192408
#  -0.01925582  0.01659518 -0.00360654 -0.03519912 -0.03012001 -0.02826695
#   0.00259288 -0.02975242 -0.00473685  0.00038169 -0.00651858  0.00234829
#   0.00134636 -0.02133905 -0.01818587  0.00017277  0.00701529 -0.02219822
#   0.00500042 -0.01639356  0.01593155 -0.01522932 -0.04798151 -0.02327565
#   0.02217068  0.04958782 -0.00152614 -0.01236683  0.03036551 -0.01265683
#   0.03350538  0.00449464 -0.01057071 -0.00791771  0.01744271 -0.00311374
#  -0.01191267 -0.04184388  0.01719413  0.00117627 -0.00818204 -0.01048041
#  -0.00097841  0.02244757  0.00621738  0.04537445 -0.022532   -0.00711546]
# ('2008-03-02', 0)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-924947c59cbb> in <module>()
#      10     for i in range(counts[tag]):
#      11         print(tag, i)
# ---> 12         docvec = dv[str(tag)+'-'+str(i)]
#      13         print(docvec)
#      14         daily_headline[tag] = daily_headline[tag].append(docvec)
#
# /Users/casperslide/anaconda/lib/python2.7/site-packages/gensim/models/doc2vec.pyc in __getitem__(self, index)
#     353         """
#     354         if isinstance(index, string_types + integer_types + (integer,)):
# --> 355             return self.doctag_syn0[self._int_index(index)]
#     356
#     357         return vstack([self[i] for i in index])
#
# /Users/casperslide/anaconda/lib/python2.7/site-packages/gensim/models/doc2vec.pyc in _int_index(self, index)
#     327             return index
#     328         else:
# --> 329             return self.max_rawint + 1 + self.doctags[index].offset
#     330
#     331     @deprecated("Method will be removed in 4.0.0, use self.index_to_doctag instead")
#
# KeyError: '2008-03-02-0'

# %%
def batch_producer(raw_data, batch_size, num_steps):
    raw_data = tf.convert_to_tensor(raw_data, name="raw_data", dtype=tf.int32)

    data_len = tf.size(raw_data)
    batch_len = data_len // batch_size
    data = tf.reshape(raw_data[0: batch_size * batch_len],
                      [batch_size, batch_len])

    epoch_size = (batch_len - 1) // num_steps
    
    i = tf.train.range_input_producer(epoch_size, shuffle=False).dequeue()
    x = data[:, i * num_steps:(i + 1) * num_steps]
    x.set_shape([batch_size, num_steps])
    y = data[:, i * num_steps + 1: (i + 1) * num_steps + 1]
    y.set_shape([batch_size, num_steps])
    return x, y

# %%
# Placeholder, variable batch size (None)
with tf.name_scope('input'):
    X = tf.placeholder(tf.float32, [None, 300])
    Y = tf.placeholder(tf.float64, [None, 1])

# %%
def lstm_cell(size):
  return tf.contrib.rnn.BasicLSTMCell(size)

# %%
# Normalized sample to initialize the weight matrices
with tf.name_scope('network'):

    state_layers = []
    multiple_cells = []
    # Initial state of the LSTM memory.
    for size in hidden_layer_sizes[1:]:
#         h_i = tf.zeros([current_batch_size, size])
#         c_i = tf.zeros([current_batch_size, size])
#         state = h_i, c_i
#         print(state)
#         state_layers.append(state)
        multiple_cells.append(lstm_cell(size))
    stacked_lstm = tf.contrib.rnn.MultiRNNCell(multiple_cells)
    print(state_layers)
    
    initial_state = state = stacked_lstm.zero_state(batch_size, tf.float32)
#     for i in range(num_steps):
#         # The value of state is updated after processing each batch of words.
#         output, state = stacked_lstm(words[:, i], state)

#         # The rest of the code.
#         # ...

#     final_state = state
#         W1 = tf.Variable(tf.truncated_normal([784, 256], stddev=0.1))
#         b1 = tf.Variable(tf.constant(0.1, shape = [1, 256]))
#         layer1 = tf.nn.relu(tf.matmul(X, W1) + b1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-afef343ff744> in <module>()
#       6     # Initial state of the LSTM memory.
#       7     for size in hidden_layer_sizes[1:]:
# ----> 8         h_i = tf.zeros([current_batch_size, size])
#       9         c_i = tf.zeros([current_batch_size, size])
#      10         state = h_i, c_i
#
# NameError: name 'current_batch_size' is not defined

# %%
# Network
